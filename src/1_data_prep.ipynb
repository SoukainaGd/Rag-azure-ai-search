# %% [markdown]
# ##### Step 1: Convert CSV to JSON Files

# %%
import csv
import json
import uuid
import os

raw_reviews_file = "../data/raw/hotel_reviews_1000.csv"
transformed_dir = "../data/transformed"

raw_reviews = open(raw_reviews_file, "r").readlines()

if not os.path.exists(transformed_dir):
    os.makedirs(transformed_dir)

def process_reviews(file_path):
    with open(file_path, 'r', newline='', encoding='utf-8') as csvfile:
        # Read the first line to get the header
        header = next(csv.reader(csvfile))
        
        # Create a mapping of expected column names to actual column names
        column_mapping = {
            'dateAdded': 'dateAdded',
            'city': 'city',
            'hotel_name': 'name',
            'hotel_state': 'province',
            'review_text': 'reviews.text',
            'review_title': 'reviews.title'
        }
        
        # Find the index of each required column
        column_indices = {}
        for expected_name, actual_name in column_mapping.items():
            try:
                column_indices[expected_name] = header.index(actual_name)
            except ValueError:
                print(f"Warning: Column '{actual_name}' not found in the CSV. Some data may be missing.")
        
        # Reset file pointer to the beginning
        csvfile.seek(0)
        
        # Skip the header row
        next(csvfile)
        
        # Use csv.reader instead of DictReader
        reader = csv.reader(csvfile)
        
        for i, row in enumerate(reader, start=1):
            review_json = {}
            for key, index in column_indices.items():
                if index < len(row):
                    review_json[key] = row[index]
                else:
                    review_json[key] = ""  # or None, depending on your preference
            
            # Generate a unique identifier
            review_json['id'] = str(uuid.uuid4())
            
            # print(json.dumps(review_json, indent=2))
            print(f"processed record [{i}] with id [{review_json['id']}]")

            with open(f"{transformed_dir}/review_{i}.json", "w+") as f:
                json.dump(review_json, f, indent=2)
            
process_reviews(raw_reviews_file)
# Out:
# processed record [1] with id [063db5f0-56ce-4d77-9b35-d0d59989a3d9]
# processed record [2] with id [345ed21d-a773-4cca-98df-e163535c50d4]
# processed record [3] with id [2dd86a03-70b9-418d-a75f-5f6e5417db32]
# processed record [4] with id [ce4fde9e-36ac-4a6d-b156-539110084cb1]
# processed record [5] with id [3faf4283-7ae1-4e4d-b9de-abcccf9f57ce]
# processed record [6] with id [3ef0b90b-f84e-45ad-94d5-4d655adcb7a9]
# processed record [7] with id [0584f5dd-075f-44e2-b899-35315ff379ca]
# processed record [8] with id [46c8d590-aa6f-4900-8aaf-7453ea22cc83]
# processed record [9] with id [bd70a98b-79bb-4579-b9e4-6128e11b7302]
# processed record [10] with id [782acfec-7ddf-48b9-89da-774c3802bbba]
# processed record [11] with id [d6893f8e-dd6d-47e5-a5bb-72e1f04d8446]
# processed record [12] with id [369c901c-970f-485f-8675-c4a62b9a2d80]
# processed record [13] with id [6b5b24e3-8279-4928-bd8c-47d21bc739c8]
# processed record [14] with id [2307ce90-a2ad-4289-a680-9d6a80182a00]
# processed record [15] with id [dbf76642-c9da-48ba-a9c4-eff4f98021bc]
# processed record [16] with id [ed8de3f9-7e84-4faf-979c-8c985acb72ba]
# processed record [17] with id [5b51ebaa-f53f-4ad4-ae91-2b84011c4835]
# processed record [18] with id [1d195477-b41a-412d-b8b4-f8b77404f727]
# processed record [19] with id [c925b12d-19df-424e-aabb-4c706c4cc7e9]
# processed record [20] with id [e532fe53-709c-4fe0-880a-34a830f7fb39]
# processed record [21] with id [b918c380-77cd-45c7-bab9-eb33477adcf2]
# processed record [22] with id [1bac9949-5746-4f37-8c68-8238b2ce5f48]
# processed record [23] with id [70db5dd0-ded6-4b36-ac84-49c2cf8c73bb]
# processed record [24] with id [c00811e8-91c2-4b62-bb24-57690fe01eee]
# processed record [25] with id [af5847b5-1e35-477b-9c13-045bec2ab0e6]
# processed record [26] with id [f481b796-9327-46d3-a677-7a8490d4b478]
# processed record [27] with id [51568847-71de-4d46-a5ac-4acea8cbb823]
# processed record [28] with id [fcb34546-5260-4efd-99e5-72fd044e912c]
# processed record [29] with id [47a25085-879d-4f8c-abff-055001b82da7]
# processed record [30] with id [415ac60d-bb6b-4cc2-8745-6e545a5f4eff]
# processed record [31] with id [e8201136-cc23-407d-b02b-703d314fea5e]
# processed record [32] with id [2d7b1329-42d6-4787-ba20-d3b21abf5ff4]
# processed record [33] with id [434e82d1-a3af-4c24-bc66-ee8d8b4f3da5]
# processed record [34] with id [ef367428-f24e-46c9-97d5-e56cfe4c4523]
# processed record [35] with id [ca906900-5c7e-4788-b4e6-ad48b6418b1e]
# processed record [36] with id [e25cfccc-2973-431c-9ff0-b638acefeb5c]
# processed record [37] with id [99102d62-efd9-45b5-ac66-ca00abf1fa9a]
# processed record [38] with id [c18a315d-9f52-418f-a31f-1aa415d71946]
# processed record [39] with id [c4d4daa1-d0a1-4fb3-8fac-4dddc0bb09c2]
# processed record [40] with id [57ae23fb-5cd6-45e5-a883-d4bfbebd7f27]
# processed record [41] with id [74367a24-6005-484a-82e6-b8209db92179]
# processed record [42] with id [335b2ab0-18ea-48ab-a173-e8c75e50731f]
# processed record [43] with id [2f1dcc78-122c-44ea-90d1-1e082d494817]
# processed record [44] with id [ae5f458d-0fc5-4a33-826c-0f6114f06996]
# processed record [45] with id [e1c667f5-dd84-430b-9c90-81ec97dd594f]
# processed record [46] with id [a1acbb7a-7b9a-4ccf-8397-6dabdb00daf8]
# processed record [47] with id [b154046b-bbeb-4621-916c-025b83f2a6c2]
# processed record [48] with id [a263b047-7e2b-4649-8ccb-a42a7bd260fc]
# processed record [49] with id [fb6b560f-3733-40e0-9f1d-d1f2f2bb1bf5]
# processed record [50] with id [cbc1c7a9-82b5-47fb-a5ef-61cd9b7f89b1]
# processed record [51] with id [14fd7138-1621-4879-80c9-d78c848712be]
# processed record [52] with id [ea8318bc-c497-4ea8-9a3a-5e404986b3c1]
# processed record [53] with id [cbce748a-4692-45cf-9809-ecb35da50e1b]
# processed record [54] with id [489b1282-07e0-4fa2-a231-f4a10fd0c0fb]
# processed record [55] with id [89ea68d2-b0be-4ea4-b8a1-c48d71dd0ed2]
# processed record [56] with id [0362db06-9313-4c94-ac57-79d9081b0694]
# processed record [57] with id [ae9d7ddb-49b0-4dcf-b37b-6ca37f7bbbb6]
# processed record [58] with id [29526c3b-ed14-4a72-8eca-500edb45c4bc]
# processed record [59] with id [c60c9f7d-7b87-4447-b602-f192326d54ba]
# processed record [60] with id [ab8c908f-d68b-4dfc-8d3a-2ff98f8fd106]
# processed record [61] with id [97fd60a2-cf5d-42c7-9fd7-f5ab16bee46e]
# processed record [62] with id [db9ce064-8212-4491-a48a-3196a74cec03]
# processed record [63] with id [e79936a4-c79e-4e3c-84c4-40d54edf65e4]
# processed record [64] with id [c3a9ac04-85c5-43dd-9e3f-750a8d5ac21b]
# processed record [65] with id [6b24cc3c-3808-468d-8294-5c35a03355d5]
# processed record [66] with id [1a931a9a-d364-4520-bfd0-78227cfec1a1]
# processed record [67] with id [144390b7-d660-481b-85be-e02831f602aa]
# processed record [68] with id [b2692680-1086-4ef9-9651-fd0fbcfae45b]
# processed record [69] with id [301ef888-f86f-48f1-a7bc-6e06032cd6a4]
# processed record [70] with id [4e800604-29ff-46e6-b130-04f479d31b38]
# processed record [71] with id [4f238d69-78e8-4a3e-90ab-9c00ee12785f]
# processed record [72] with id [1ca06c25-152e-4d68-9013-cf63892a0147]
# processed record [73] with id [cccbb46d-0574-415f-8324-9ee40a712d54]
# processed record [74] with id [e7a02a05-7685-4a03-9c92-1aa1b12aad4c]
# processed record [75] with id [ec91d3f6-f007-4185-abb5-af5348dc70fe]
# processed record [76] with id [f3444dfe-c40e-468c-92cf-e6ba3f34d156]
# processed record [77] with id [8d109887-00f2-46a2-9a40-175317bf1217]
# processed record [78] with id [d2fbaab3-a969-40ee-932a-02930b83c649]
# processed record [79] with id [b2433bb4-0ad1-48c6-b918-0b44b7a2e3c5]
# processed record [80] with id [fdaba69c-64f9-4960-a1d8-39919b8ca40d]
# processed record [81] with id [84075ccc-af00-4fdb-8a9c-27933446323c]
# processed record [82] with id [3e32f770-5354-4b61-9c3a-35bf1b2fc899]
# processed record [83] with id [350c4aab-a0f4-4185-9798-c9f884bf807f]
# processed record [84] with id [2f6cbc4b-afc0-4821-9e67-34d28b560f26]
# processed record [85] with id [b4c42571-6558-40bd-aae8-c6c5012fa667]
# processed record [86] with id [d20fa84e-2468-4a31-be78-95f1b7a7df4d]
# processed record [87] with id [9f9af318-5e84-4fe9-805a-f04d3fc48839]
# processed record [88] with id [51cc781d-2a33-4af3-ad35-7ac9c9069f0a]
# processed record [89] with id [7e604ef7-c647-4e04-aca7-2dfbcad82952]
# processed record [90] with id [9a667274-fa73-437d-a97c-e0996e741609]
# processed record [91] with id [4179c5ea-581a-46e5-b9ba-3b267a13bfe6]
# processed record [92] with id [f3fc14e6-d21e-4b12-935b-926414727e96]
# processed record [93] with id [8da721ff-207c-4d96-8c74-94506f9ff0e8]
# processed record [94] with id [f5f944d4-28eb-43e7-899c-f7cdaf81d9c4]
# processed record [95] with id [d4c56f66-7e73-454d-9316-8dcd74b9cec5]
# processed record [96] with id [576dffb4-a08f-4d72-8de5-92fb739f0c62]
# processed record [97] with id [a1a01dd1-8bf7-4c9c-96b6-6bdd33a7a006]
# processed record [98] with id [e1e7f908-d244-453f-898f-09bb25642187]
# processed record [99] with id [5a45b654-4321-497b-9f24-e6ea62311d85]
# processed record [100] with id [43595ddf-a775-4fa3-930e-a0101c9909e6]
# processed record [101] with id [e6d5e10c-bc7b-4651-a1ce-6d9ea22f9a8b]
# processed record [102] with id [d58129b7-1186-45dd-9c93-0865565a1c38]
# processed record [103] with id [7bcfc317-eafb-4734-a951-8c3faac164ae]
# processed record [104] with id [5dc7234a-b3bc-44a5-8941-8306a3954727]
# processed record [105] with id [a7f94c14-efb8-41e8-946d-f3fef020f211]
# processed record [106] with id [70e4cd59-6901-4b70-bc30-e00bd11074d8]
# processed record [107] with id [1e303432-86dd-41f4-adb8-4177a58c6b2e]
# processed record [108] with id [7024233e-f5c4-491c-a15f-6e67281d2ead]
# processed record [109] with id [53b85842-2226-45cb-a5bc-2087bef1ad38]
# processed record [110] with id [3ff6d104-9b88-4cb0-9dae-b1d20fb7d459]
# processed record [111] with id [26bc23e7-4ec0-4c87-bc7a-395c9148bc4f]
# processed record [112] with id [9dca85c7-15ae-43e2-ae71-788bf6f5b4ff]
# processed record [113] with id [ca6b3e88-1bda-4d31-8298-606f84c4b2a5]
# processed record [114] with id [b4dd3e96-fb25-4978-8ce1-5fa156ebcef5]
# processed record [115] with id [622a8e84-ef9d-4f2e-88c1-ade5c16344aa]
# processed record [116] with id [0a91b5f3-2aa3-476e-91cf-a3d0b0b2e823]
# processed record [117] with id [320a882c-c3e4-4619-91b5-a580475d2f54]
# processed record [118] with id [b1190bd8-fb37-4fb0-8551-a6eb628b4e8e]
# processed record [119] with id [e358e08a-2a7c-4d19-b74a-076284472b4c]
# processed record [120] with id [9fec2c41-c4c8-4bee-b7fd-7fef0d1853d5]
# processed record [121] with id [471006cd-cdbe-4e71-ae9e-fc2e4644701f]
# processed record [122] with id [ebc637b9-0ee6-4f0d-ad2e-f79ccca96fd6]
# processed record [123] with id [7d4443e6-cc89-4b24-a55e-8fa122e6b40d]
# processed record [124] with id [8f327b12-3df3-455a-9957-fc390d03b84f]
# processed record [125] with id [2354c823-09b2-4a3c-a16c-80861f00ffb2]
# processed record [126] with id [56aa0294-4992-482f-8fe8-29008a051657]
# processed record [127] with id [ad758681-ee0a-40ed-b8c4-53aad6a80ee7]
# processed record [128] with id [a158598f-dff2-4f56-a484-11f6bfbb9e87]
# processed record [129] with id [2021655b-8643-4d46-b0fa-c45a3b2d872d]
# processed record [130] with id [90112817-c1d2-4d49-9ce0-49a64208c5b6]
# processed record [131] with id [0078abb3-25d2-4efa-976e-54033305a40b]
# processed record [132] with id [6b4eb4e4-8d48-4b85-b930-e792d107921f]
# processed record [133] with id [9e7a689c-7094-479a-9f52-8ddd82ab7058]
# processed record [134] with id [06e52ccc-bad8-4b47-96e1-a0877b7e7592]
# processed record [135] with id [87538e2c-a325-44bc-9651-56cfcc19d76a]
# processed record [136] with id [10220fdb-ec73-4f50-bd2c-113b82678ea5]
# processed record [137] with id [f711e0bf-8e44-47e5-8b66-d386a997c63b]
# processed record [138] with id [e09274a2-af93-4746-8c13-82615c99ef79]
# processed record [139] with id [c79b68d8-34c1-45c5-92f6-b42a46e29ad8]
# processed record [140] with id [d952bb4b-6fff-45cd-be31-5cf8d143aa23]
# processed record [141] with id [ac21d89c-3665-4ea7-9f48-6efb8d3e153a]
# processed record [142] with id [a4454225-f994-4684-a0ed-307f17e8d2f2]
# processed record [143] with id [4ce43fba-5946-4b99-aa96-307df0dc5cba]
# processed record [144] with id [e1d92eba-eba8-4f9d-a240-6cea28b64099]
# processed record [145] with id [6aa6c629-4449-4e17-94e2-38435b25574e]
# processed record [146] with id [6e397bfa-d2e9-47a7-9ac4-83594c50042e]
# processed record [147] with id [ad5763e4-3948-4c69-bebf-ee27d78c8bfb]
# processed record [148] with id [57a2f797-1b76-46b5-b6a7-42ca92bb5f4b]
# processed record [149] with id [cf8bf5b5-3304-496a-a931-5f7e80c3a637]
# processed record [150] with id [e40733e6-7384-4d56-a126-aae783c4f994]
# processed record [151] with id [bf92a4bd-fc29-47ca-acc5-7a5675c7e92b]
# processed record [152] with id [1d6c1122-3081-4265-bee6-c211cfb95954]
# processed record [153] with id [0328c84a-625b-4432-a8bd-f4009911eb48]
# processed record [154] with id [3a286149-a592-49b6-a9ba-e7b8792bc9bb]
# processed record [155] with id [e3501135-8e2c-4c64-bcc4-de79221ecdc2]
# processed record [156] with id [00bc86b1-70ae-47f4-8b3a-b9b3f4b9d10c]
# processed record [157] with id [981764c0-739c-4d42-82f4-9d4fc9b42b7f]
# processed record [158] with id [94a39018-4317-4817-a9ed-a914d408bde4]
# processed record [159] with id [8cffcae0-8d89-4f71-9eae-8700f2ccd51f]
# processed record [160] with id [8ef095db-9a38-432d-9723-9e7ffddcdaf9]
# processed record [161] with id [8a5bb5fb-76d6-4c3c-a832-998a7ff679ba]
# processed record [162] with id [e1157a90-e951-4cd9-986c-730a068254ef]
# processed record [163] with id [08a05df3-5d15-4988-8eb6-8583e6b76c48]
# processed record [164] with id [95bd321d-e085-4631-9179-2b2933620551]
# processed record [165] with id [80e7b4dd-d5ac-4d18-a604-0a68127e0e27]
# processed record [166] with id [1fe1415e-0762-4a63-9e4d-654c1c7d2bfb]
# processed record [167] with id [207044b3-c917-41b3-a05d-767f93aeec07]
# processed record [168] with id [2f806e23-1190-4689-aabf-8ca7e9f21658]
# processed record [169] with id [a29d5c92-0426-40a5-bfd3-ed98af0be654]
# processed record [170] with id [decb90f0-02fe-4692-82af-98eb9cfa3b26]
# processed record [171] with id [c29d8339-45f3-42b3-9a09-870120f6e6e9]
# processed record [172] with id [5af09f14-ac1b-4293-a176-9e82a6b3d693]
# processed record [173] with id [f5998e38-95ff-47f0-90ed-a600b7f757c6]
# processed record [174] with id [52135d8b-0f41-434e-9706-bab00a774778]
# processed record [175] with id [0d154a02-b344-42d2-a143-03a227e46344]
# processed record [176] with id [2f973c45-96a9-4388-b568-3d99ba5742de]
# processed record [177] with id [a4dc4ec6-3f09-4b50-9842-d2d5d0cba142]
# processed record [178] with id [e69d049d-cd3b-4d37-b78e-2880fa2cdcd5]
# processed record [179] with id [cd0d6db7-3439-4873-a682-248d8357d849]
# processed record [180] with id [36fb73d9-9c90-4664-9e4e-14298c24eff7]
# processed record [181] with id [a1683aad-ca35-489b-91eb-e15df87373e0]
# processed record [182] with id [c5c3f37c-5d8f-4990-b617-0abfacbeeab0]
# processed record [183] with id [3a937da4-b929-4ea4-93af-bf75015a7579]
# processed record [184] with id [4f33b64d-80dd-4d27-8fe4-1fe985ef7800]
# processed record [185] with id [7a89c3f8-ec1c-4d65-8070-e35be31ecbc6]
# processed record [186] with id [84eb8c13-d416-4719-9f73-13d53a36a2ea]
# processed record [187] with id [e0219b20-a19f-4250-9caf-74cc7a08c35e]
# processed record [188] with id [04a46277-0534-478c-8fce-59f8250f8510]
# processed record [189] with id [f35e06be-84f7-4305-9360-be7a833d35e5]
# processed record [190] with id [c0910ae1-51ed-4926-b35b-04a38c73df39]
# processed record [191] with id [43e9798e-0fe0-41df-9fdf-32935470efd7]
# processed record [192] with id [4e098621-a3d9-48fa-8c7e-f689b9cc7868]
# processed record [193] with id [de01f579-19be-471f-a044-30a1d92584c1]
# processed record [194] with id [7d6cd444-62ab-4786-b113-e08944164d35]
# processed record [195] with id [930981de-d512-4ce6-9e3d-4b9c6ced0600]
# processed record [196] with id [5aa43627-a29a-4408-9f49-22dbe90cc336]
# processed record [197] with id [8ac5deec-c1a3-48b6-b85e-7886215cae8d]
# processed record [198] with id [96d68b2e-2ee6-46c5-868a-f6fb2589605e]
# processed record [199] with id [311aca58-62ea-4e1d-9022-9cdcd2d36a03]
# processed record [200] with id [5df3aad9-e83a-4c02-af8e-429a9a9ea0e6]
# processed record [201] with id [fa2a06d5-2972-43c8-ae37-62cc031f8be2]
# processed record [202] with id [7e9bbdb9-30e6-47fd-9c70-25cf8c197bc6]
# processed record [203] with id [def4f219-4e5c-4396-9d53-23bb62ed87a3]
# processed record [204] with id [691dac63-79fc-4a7b-b436-e618f52c7eb5]
# processed record [205] with id [c80db13a-44fd-4416-acdc-4a749018fc3e]
# processed record [206] with id [a3687750-5bbb-49a4-bb9d-0e6f7f1a7f09]
# processed record [207] with id [cd1e14b6-0472-451b-8478-af5eedd7631c]
# processed record [208] with id [f0582d99-4443-4111-a4d9-62776207f68d]
# processed record [209] with id [1a04052a-0afe-44ac-aa33-b640e03405de]
# processed record [210] with id [266ff2b5-af2c-4e3c-960b-662df044d54a]
# processed record [211] with id [2ce785da-6747-4175-8048-a68a55771506]
# processed record [212] with id [049d010e-c0a6-47d3-a20e-3e90f0a3ab76]
# processed record [213] with id [970e3132-f353-40aa-a7ff-85beae1d8c89]
# processed record [214] with id [7490762c-ad65-4a6f-ab5f-8ffc30ee1a58]
# processed record [215] with id [cc7ea106-e5a5-4e6a-a99d-0e50c125a940]
# processed record [216] with id [c3d8278e-22b4-4c2d-af60-c804a942cd2a]
# processed record [217] with id [56a13e14-cc9e-44a0-8054-ffe546f5a732]
# processed record [218] with id [f7a8fab4-53b9-48aa-acdd-317da14d1f9c]
# processed record [219] with id [2b9f155f-8e3b-4042-9048-43f1d82474c1]
# processed record [220] with id [e0b0f391-5337-48b4-9573-6c65b4e34d4f]
# processed record [221] with id [c24c12d1-e6bc-4210-8283-eb7687502ac2]
# processed record [222] with id [c237928f-a9d1-453f-a3b0-dfe669a692bb]
# processed record [223] with id [33189332-83ae-42e9-89a5-108d90e9eec2]
# processed record [224] with id [9ac35685-78d5-4dd5-8ff1-64b6f1e860fa]
# processed record [225] with id [f9d2e860-6ef5-4ebd-a4bb-e90ad1c413d7]
# processed record [226] with id [8c484840-f47a-4a06-924a-29ec8c6b1e35]
# processed record [227] with id [6436b672-08bb-4fd4-abc4-153e158070a5]
# processed record [228] with id [b448cdb3-748b-44c6-87ff-f6099505b6ea]
# processed record [229] with id [7282be1a-3fec-4bdc-afad-da98321c9c2b]
# processed record [230] with id [d4e6e171-9090-4542-ac95-0e45f0f413ee]
# processed record [231] with id [81950c45-a0b2-48af-b963-9790671f2f01]
# processed record [232] with id [e8b17d9b-6c79-4cfa-b5b5-c63857404faf]
# processed record [233] with id [ea9c16ea-9714-4378-b2d6-d768303d6243]
# processed record [234] with id [13d9e0b7-e02d-4f45-9f39-cedc92c274fa]
# processed record [235] with id [2fc7ff1d-701c-413f-9ee6-c18a09fe0efd]
# processed record [236] with id [a1e9e233-f4c1-4c78-8951-dcc88d865220]
# processed record [237] with id [7a16aae7-9ca1-4630-8fe4-4402309118e4]
# processed record [238] with id [d1e5eef4-91b4-43e6-ba93-636d6c1e9490]
# processed record [239] with id [e8181d29-31b6-49d6-b2ea-cf84990c0e92]
# processed record [240] with id [ee2578b5-0be2-4b34-80eb-a77cf1fcc60c]
# processed record [241] with id [4c84d040-d0c1-4787-bf35-4116048bfc32]
# processed record [242] with id [dc81bb6a-7769-4369-be91-16718ccff576]
# processed record [243] with id [071eafb5-eb8e-4f04-9803-57b2097a7b3c]
# processed record [244] with id [859b12f7-1eb6-4e17-bfb3-f8af039c1ea5]
# processed record [245] with id [87e182fc-5b0b-4603-a63c-2e582ac0fd68]
# processed record [246] with id [cd9e6699-648d-48e8-a6f3-7746eb54d66b]
# processed record [247] with id [727e7ddd-9a10-4d9c-b74f-b3b20f51261a]
# processed record [248] with id [4f58b5ad-bd20-494a-8a11-fc66f5856d69]
# processed record [249] with id [4a90bb8e-c07e-4e59-941d-259df771ce4b]
# processed record [250] with id [7f045f5c-07a7-4d51-a351-d695068c358d]
# processed record [251] with id [3ee68b07-75e6-4458-b935-65ea7a26348f]
# processed record [252] with id [2179de91-d9a3-45d4-9533-620069101cd4]
# processed record [253] with id [a220e3a5-d834-4d14-994d-05bf7227f2e7]
# processed record [254] with id [b93ada1d-b67b-4592-9274-e6a760e60bd1]
# processed record [255] with id [97cfe9de-5120-47c1-9948-5b666f7ac104]
# processed record [256] with id [d961190a-26be-4901-b426-c0315eb39dac]
# processed record [257] with id [9c7163e0-4d02-4a4c-a74a-8768a8ac561c]
# processed record [258] with id [d97be7c7-d9c1-4117-a1e8-603a25c26892]
# processed record [259] with id [17d80399-c760-419c-b8ef-41c25ab325d4]
# processed record [260] with id [04472855-5f18-417b-9e01-6bdf1e6e4183]
# processed record [261] with id [3c62e7aa-b620-442a-897d-0fd9aa87311d]
# processed record [262] with id [cca83546-0976-49d8-91ac-af20821a9485]
# processed record [263] with id [9a68af0b-f0de-498b-bce1-8badf574e56f]
# processed record [264] with id [0e1aca88-0354-4f9d-ba5d-6f4b4a0f0d78]
# processed record [265] with id [5b33c5f3-b2e7-42c9-9fe9-6f11fbf9951c]
# processed record [266] with id [fccde1de-40d8-49b3-b085-e2e164604ea2]
# processed record [267] with id [01e2a0f1-6833-4dc3-9ec5-d7da885e4e41]
# processed record [268] with id [d0b6bdfc-63fb-43d2-9d4a-b8d616e7b39f]
# processed record [269] with id [c05a6de4-8f94-434c-bd78-59dccb865520]
# processed record [270] with id [ce30b2c8-bfb6-430b-985b-f877371fe4b3]
# processed record [271] with id [f3e1e818-5894-4274-b3f9-61a474a08873]
# processed record [272] with id [7c82a085-c8f0-4dfa-be07-d10cfa082dc8]
# processed record [273] with id [1bb79354-5a34-48b9-84e1-baff91a5956b]
# processed record [274] with id [7a06ecab-d034-4115-b1fc-7053799cfeb0]
# processed record [275] with id [e602bfbc-6a92-416c-bac9-fcc75af52bff]
# processed record [276] with id [b4370c4b-0169-410f-92e1-a6e818aafda4]
# processed record [277] with id [0188b73a-cd37-42e1-93aa-21956ca77484]
# processed record [278] with id [ebb071bd-84b1-4484-a65c-05a6bab05232]
# processed record [279] with id [06d8bda2-11d9-4b24-9d4e-d9ba183047b9]
# processed record [280] with id [d807522a-9219-45fc-a9bc-3d2cd7be682c]
# processed record [281] with id [a1ca61af-4f95-4c99-b3ca-afc6463d5a66]
# processed record [282] with id [d5889ae7-b7b5-4730-8414-1dc124f5851a]
# processed record [283] with id [22f854a1-2ba9-40c1-b4e6-0d2863d638ec]
# processed record [284] with id [aeff9cb5-08d3-4364-a223-6f07a467b19e]
# processed record [285] with id [79ffc0f7-481f-4ab7-9264-9b59043e9bcb]
# processed record [286] with id [760b7461-83a4-4ad8-9fc5-aa67fd41a6fe]
# processed record [287] with id [9d72ab69-efb9-4e8b-8890-de9a5b58d2e3]
# processed record [288] with id [367feff3-91c5-4c35-8516-fec5e38a2ccc]
# processed record [289] with id [53393b2d-4de5-4784-a06b-267b091e4040]
# processed record [290] with id [c70e2bdc-4d75-435e-b447-81bc016145a5]
# processed record [291] with id [246def88-2f88-4639-984b-5b858942b549]
# processed record [292] with id [a31fc34e-461d-46df-85ec-b6b516a7268d]
# processed record [293] with id [6e45510d-d9cf-4dcc-bd0f-1d5e825daedf]
# processed record [294] with id [a55a10b2-ee9b-4432-89d2-bcac72097419]
# processed record [295] with id [093c7817-8507-4e54-aea9-3f157ab5c41d]
# processed record [296] with id [d6b826e0-69a7-44e7-82b0-bd4ad806d5af]
# processed record [297] with id [05b031f8-86e0-4c2e-b73b-bdd9ffe26792]
# processed record [298] with id [a5bdbe38-7f70-40c7-a83c-495d95af0d58]
# processed record [299] with id [9816cd62-af7f-4d42-9062-823ffa640c1a]
# processed record [300] with id [643e7aa2-a791-4940-94fc-5c075c9d1903]
# processed record [301] with id [b35d12db-b88d-44b8-8b14-486410d2da9d]
# processed record [302] with id [af97fb7c-9c1d-4805-bc91-ed1a1f370276]
# processed record [303] with id [964b9d5f-e56d-45a1-aa07-2fb75e66a901]
# processed record [304] with id [3c5229c8-6e62-4331-9018-2cb85e6b5133]
# processed record [305] with id [46df1ee4-70bd-4563-b2b9-fc0f2d8d71c0]
# processed record [306] with id [7afb8780-03e1-4cb2-929a-6c228a2c9307]
# processed record [307] with id [068042b9-fd05-4771-a1ae-35b5d7bb6f29]
# processed record [308] with id [04d7699d-7ac6-4ac3-b5d5-9f782ac43e75]
# processed record [309] with id [3d14dfb0-eb41-4078-baa3-e8dc78f4c014]
# processed record [310] with id [942b2e62-ab17-4d1d-ace4-975c49902d9c]
# processed record [311] with id [7fb67e7b-088e-4356-956c-507ab7544bf8]
# processed record [312] with id [717a2fff-1bc9-4f40-881e-b55d8c8391d5]
# processed record [313] with id [84842c6d-a6ed-4737-9394-83f4abe42a5f]
# processed record [314] with id [2481129c-7019-4be0-98f0-c4466a64ccd2]
# processed record [315] with id [20e64816-92aa-4d67-91da-59a86c40fc26]
# processed record [316] with id [5592f62d-ca4c-4eef-9e30-433e87916a50]
# processed record [317] with id [43b0894e-be6e-4979-ac0c-ee75e993de79]
# processed record [318] with id [8067ba5d-7af5-4da2-801c-7ae7ee783c51]
# processed record [319] with id [6a988b8a-cf39-4844-8f58-d1021e5efda4]
# processed record [320] with id [e7118414-eb43-4dfb-ab00-293404fc98db]
# processed record [321] with id [4c307746-5140-4264-8151-9632585e522f]
# processed record [322] with id [f6087a3b-0ec5-42e8-86b2-8b4449f9c8cf]
# processed record [323] with id [d2685389-a5ac-4b1d-a5e8-91d3f92853ce]
# processed record [324] with id [b45529e0-71e1-4e66-ae1d-d148826e52c1]
# processed record [325] with id [c7d8f45d-c4e1-4502-99c8-546de3c54960]
# processed record [326] with id [4c3b1bab-d614-478c-b4ce-b6c6e0324049]
# processed record [327] with id [7ef6999c-4077-484e-938c-e67d0a9322bf]
# processed record [328] with id [a6df1112-dc57-4d56-a63b-d5d3def1e60d]
# processed record [329] with id [d6de06a0-96fd-45d9-a3ab-5532604df54f]
# processed record [330] with id [d6eee713-b840-4a36-8c54-84fe06e8c9ac]
# processed record [331] with id [0a511e7c-feeb-4b41-9d98-0764df7734c4]
# processed record [332] with id [5bdc5fed-c45e-4d3b-a4b3-17d78eb46f0b]
# processed record [333] with id [e5a4e482-83bb-46b0-a0a9-2c9048a0d939]
# processed record [334] with id [d8a3bdd5-20a9-41af-8b17-d639bef2a319]
# processed record [335] with id [66a7698d-a0cc-4f74-b825-d02dbd6c642c]
# processed record [336] with id [3d5cbb38-898c-43dd-9dc2-2b8ad3456eb2]
# processed record [337] with id [04b366ca-324e-4061-81e7-53fa524ba003]
# processed record [338] with id [5854510a-c244-47ad-91c6-8fe0a9ec8568]
# processed record [339] with id [758aa9e9-48fd-4c62-a93c-37f9a54be16f]
# processed record [340] with id [c64672d4-386f-4251-b55a-d192619754bf]
# processed record [341] with id [c6fce7ec-c0cb-401d-8354-d5acb894a57b]
# processed record [342] with id [e77675cb-8b79-42f6-88e9-31a18b6df765]
# processed record [343] with id [b0f12cf6-a6c7-432b-b2f0-4bad690f356b]
# processed record [344] with id [b49c1d6b-4bd1-4387-b545-9a58a152e757]
# processed record [345] with id [aa384de6-e0bc-4ce9-99d4-c3a85a0f4a86]
# processed record [346] with id [92c12297-ffd1-46ed-99d2-72dd563a55a6]
# processed record [347] with id [3a7896df-101f-4bdb-9896-2e51e07e8f81]
# processed record [348] with id [a64189c3-3976-4f28-a4a4-9cb7ba0e49cf]
# processed record [349] with id [51a816cc-c13c-4e03-b47a-3fc4ccc490e3]
# processed record [350] with id [c8739b72-b739-42d0-aa61-6f37ac879801]
# processed record [351] with id [6749bda5-7507-41ee-a0b6-83e0b91af1b8]
# processed record [352] with id [6153c9bb-86bc-43de-a8a9-eda7a4beb135]
# processed record [353] with id [cb52e83c-bd29-4b75-a4b1-a260d3b90b04]
# processed record [354] with id [0cada9f7-c24f-4820-a4a1-b324f58a5ca0]
# processed record [355] with id [69e85ac4-b31c-4bfe-af1c-89b1b94dbcd3]
# processed record [356] with id [a46db810-1118-4b9e-bf8c-e34c22a1cf13]
# processed record [357] with id [628627e3-daec-410b-8c97-040c82ca0b55]
# processed record [358] with id [72dec4f1-cd0b-4290-b015-78be2f2e904a]
# processed record [359] with id [fdb406ae-e748-49e2-ab57-3b808b290552]
# processed record [360] with id [3be578ba-8fc5-41f5-94f2-0ba289d4209b]
# processed record [361] with id [d7f8d729-2926-47ca-bb8f-8293d806ae76]
# processed record [362] with id [ce929cb7-d985-4996-b2d2-0b6ffff9d7e1]
# processed record [363] with id [b72b9a67-c997-497a-ab53-8c5dd30c43a2]
# processed record [364] with id [90931553-f2e9-4047-827f-2fa6fc4e8d06]
# processed record [365] with id [ffac1bbd-bb12-421f-a465-209211774f4c]
# processed record [366] with id [616b725b-e484-455e-8670-7c37d1fced63]
# processed record [367] with id [982121f0-1f4a-4125-989b-971f2c49bcbb]
# processed record [368] with id [49bc041b-0360-48e0-a8bb-21a34bb0d67e]
# processed record [369] with id [aac10459-884a-40d7-af97-9d05208c2681]
# processed record [370] with id [eeac5a7f-9944-4cd7-ba9e-c7479cc663b7]
# processed record [371] with id [7cb78616-5cee-49c4-82a6-474d4e3b7532]
# processed record [372] with id [ea1a5389-a5a4-4acf-8294-670f6a14a799]
# processed record [373] with id [115e1ffd-1d50-4d6d-81f7-72a89571efbf]
# processed record [374] with id [5c6641b0-cb8f-4c79-a82b-08fc15b73b2f]
# processed record [375] with id [9945faaf-9fe9-48de-b388-0ec4b64fa6df]
# processed record [376] with id [b9b0102c-509b-49c4-a0a9-66c6b52c2ea0]
# processed record [377] with id [b5ffc469-9afd-47e2-b997-eb3926f41b63]
# processed record [378] with id [2ab79da7-6e26-4cda-b9a4-322ccc76e963]
# processed record [379] with id [7a771fa0-6b23-4b49-b0d9-1616df71a834]
# processed record [380] with id [62f65313-38fc-417e-a204-bf404dcc3137]
# processed record [381] with id [95ed564e-8483-49df-b7f6-5026d586b2b3]
# processed record [382] with id [25bc98f3-5054-49a4-a445-02ad46dd2137]
# processed record [383] with id [0e5f3452-3d3d-4565-a55c-2dfc6b8860b2]
# processed record [384] with id [ab2a22f0-c3e0-4eb1-88d4-722a3d0a0aa2]
# processed record [385] with id [1143d53d-2595-4741-8075-64ae99b9fad1]
# processed record [386] with id [4d359815-6f76-4965-981f-b3ae8b4eac00]
# processed record [387] with id [58de29a3-e1e2-4637-86dc-a62f0f2123a0]
# processed record [388] with id [02dda481-529e-45bb-85da-ea29c4277189]
# processed record [389] with id [d3c52cf3-bcc1-4299-b857-ca9d95b04bee]
# processed record [390] with id [1820d7af-d4c3-4287-b3bf-b6975fb3a45e]
# processed record [391] with id [92a040b7-d994-4c1d-9507-5b486e2ffb61]
# processed record [392] with id [7d0411ab-7090-469e-a9e7-da1499f4b805]
# processed record [393] with id [01b2ff64-c62a-4c25-93c0-f759061f9806]
# processed record [394] with id [f391e348-55ff-4dbe-b377-4b110938ce55]
# processed record [395] with id [520aff62-b7d2-4189-b7b5-16441c7e1712]
# processed record [396] with id [637d19a4-6a2d-4473-b4ac-42a141d798d7]
# processed record [397] with id [d9a4b5f5-0023-4708-8501-8c92af16fc65]
# processed record [398] with id [9c34fdd2-25dd-4f18-a99a-86ecf3a9adc9]
# processed record [399] with id [2808284b-a3e8-4862-8fdf-e2a0712ebc73]
# processed record [400] with id [a3851038-31fe-4aee-b7dc-83ed3938821a]
# processed record [401] with id [3a63712e-0f44-4d40-8ba8-5c3ce6620e06]
# processed record [402] with id [c704265e-1c8d-4054-bd7e-6b42ce159bff]
# processed record [403] with id [6db1d397-ff4a-433b-b21c-27f69560e372]
# processed record [404] with id [5eb77c2a-e379-4c8d-995a-719eb9088992]
# processed record [405] with id [360efd20-4ad4-46a7-881d-7a0e1fe7986b]
# processed record [406] with id [ea237e4f-7859-4d81-9ead-b8ce0773aa7c]
# processed record [407] with id [1d1b89a2-fe1f-4598-aa5b-fb07224791a3]
# processed record [408] with id [8af1c0e4-e927-4440-8873-1584da93ee1c]
# processed record [409] with id [7038713e-f805-470d-b796-7d018c02fe9f]
# processed record [410] with id [2110dd3b-9946-4ff0-9afa-3e232edcb3bc]
# processed record [411] with id [bc1d2ef1-7c85-4e4a-9df3-fc00bb10b285]
# processed record [412] with id [d0268ca2-9fda-4975-8e55-a93592989b20]
# processed record [413] with id [8fb1d555-ec86-42d7-8ece-71c7ccb12bc8]
# processed record [414] with id [5df0e923-2a0e-4191-bddb-7bad61befe3c]
# processed record [415] with id [b1940fff-96b2-4db9-a1c4-88723fb38f04]
# processed record [416] with id [3b48a335-a82d-4705-ab73-3926ce9c714b]
# processed record [417] with id [6adac301-a2f3-49fc-844a-44483f582a62]
# processed record [418] with id [750dfecc-6dfd-4ef5-88d2-c39a46e3f30b]
# processed record [419] with id [634ad3b4-13d3-4444-b6c9-a7c18d3ce014]
# processed record [420] with id [097a2c2e-a096-40ae-a07c-84278dd2adbd]
# processed record [421] with id [17304634-014d-447c-8c0e-9a0a3b24f2d3]
# processed record [422] with id [128d995d-52fa-40c8-995d-d09b76a4e849]
# processed record [423] with id [0dec50ab-2fb1-410a-8415-11cb5d94ffee]
# processed record [424] with id [579db268-7efb-4eb1-8aab-0cbd3435c5b8]
# processed record [425] with id [2d5c5547-3e9d-40ca-a4fb-dacdcf90003a]
# processed record [426] with id [ac082b3b-f595-4660-94f8-568b1a197a57]
# processed record [427] with id [8fb0a47a-602b-446c-bf02-b2273da20232]
# processed record [428] with id [e32664ea-ab50-4096-8c98-5d1160d5bf19]
# processed record [429] with id [d0c4fb49-5224-444a-a5ee-cf6c7ef8e935]
# processed record [430] with id [0e84fd93-9bfe-4c71-81fa-2e8a2d409b5e]
# processed record [431] with id [7eb3ded7-2c1d-4352-8f9a-7bcfac1413e0]
# processed record [432] with id [4fd3e31b-23a5-4036-843e-a5ca0c317e9d]
# processed record [433] with id [83e7cee7-17dc-4fd3-8d59-b457596d4336]
# processed record [434] with id [7669b247-ff58-45b8-b16d-0ae5475a5e7f]
# processed record [435] with id [f5ab7c81-a9c5-4f76-a626-61dc5d1de42c]
# processed record [436] with id [30b83b34-b365-4694-8acc-ca69759260b0]
# processed record [437] with id [f96fbce4-334a-49bc-a6c2-51c3263e4d09]
# processed record [438] with id [5e25cdb2-fca8-42ab-9683-36614227edce]
# processed record [439] with id [5c8c174b-98a8-4dac-9738-a17161ddd455]
# processed record [440] with id [1408db19-ae14-41c4-832a-2b88b62d9bbb]
# processed record [441] with id [8c17b359-425f-4d14-863b-63b14e00e137]
# processed record [442] with id [fea84a1d-be8a-4814-9576-2321b57c536e]
# processed record [443] with id [94f93eb3-340a-4200-9897-fe41a7edf7c3]
# processed record [444] with id [69be548f-babf-43d3-9b62-6f3b8c6688a4]
# processed record [445] with id [7b3435a1-62ef-44bb-96b5-c6c3c0901e34]
# processed record [446] with id [9a76e205-b0b1-4fa2-aa0f-4b9f005a41b4]
# processed record [447] with id [23f921cc-7064-40c8-9a50-b0c8b46e1635]
# processed record [448] with id [dcdae671-5ba5-44e1-bc06-704c06ee8008]
# processed record [449] with id [e79ebf65-be91-4a02-a045-8f55f81bd43f]
# processed record [450] with id [c75938d7-ad9f-4e12-b6e5-7d5b7ad65bdb]
# processed record [451] with id [b0cab04c-5930-4227-bbab-ad3d8bd851df]
# processed record [452] with id [b7deb923-ab1d-43b3-827d-bea28e33e4a5]
# processed record [453] with id [da935773-5160-44fd-950e-e1ea56d5cb8e]
# processed record [454] with id [188b0ab2-8db1-45fd-8af7-b07a03f256fb]
# processed record [455] with id [dd6e4d0b-8c98-43f9-92a5-ec528fb8ccf6]
# processed record [456] with id [d95eba40-a068-40a2-9ed9-0dacdd1c6c2e]
# processed record [457] with id [12b398b4-271e-4947-8a64-a9f7c81c4127]
# processed record [458] with id [2c9d1786-bc10-4ebd-b7ed-b959c8f4dc0c]
# processed record [459] with id [ce197a04-8a8c-4311-ae45-e91961b259d4]
# processed record [460] with id [8ac59dab-6a3d-4ed6-b8d9-c3711446d381]
# processed record [461] with id [65e6862f-3cb9-4b02-a389-393f173d8086]
# processed record [462] with id [8c3dbb7e-9e61-4431-9a35-d76b7db8184c]
# processed record [463] with id [a4f56adc-73cd-465c-824c-faf1f9d63098]
# processed record [464] with id [d6130f1e-0c7a-48e2-94c9-ee81e40bd1e5]
# processed record [465] with id [ca491de3-1514-44eb-ae36-924688229b38]
# processed record [466] with id [91ce130d-6307-40a5-9be4-8f054f04db95]
# processed record [467] with id [8c1bf58f-969c-44c8-a99c-1fe7c15f4a93]
# processed record [468] with id [4bc169b0-645e-4453-b33e-60245db29dbc]
# processed record [469] with id [06584417-5331-4cf9-9a29-2cc951e0d90c]
# processed record [470] with id [97a25951-b275-4512-b140-d8394a0a5816]
# processed record [471] with id [11824b7a-5f90-4a5e-8b7b-73860602a0ef]
# processed record [472] with id [2a5945c0-69ee-4531-9cda-707458449c6c]
# processed record [473] with id [9ad9cea4-06cc-42d2-9c9b-a4fea3c550cd]
# processed record [474] with id [deeb5024-029f-4f1f-b084-2c5b1e6ae50f]
# processed record [475] with id [aa4ba0f1-c9c2-401c-9d46-a588ee4bc816]
# processed record [476] with id [979ca348-7ac2-4ea4-87ec-65a5ef6e09dc]
# processed record [477] with id [67bd07df-efec-4dd4-a52f-b7b0b8ec4646]
# processed record [478] with id [5ddaa3c8-2d50-48a5-86c3-18a45dc83e86]
# processed record [479] with id [9042704f-dc06-4321-9db4-eed8daef7444]
# processed record [480] with id [8fe8f1d9-6e4d-4573-a71f-9df7906c1880]
# processed record [481] with id [cbad000f-c2bc-417f-9afe-133148498656]
# processed record [482] with id [92e1a0cf-e1e9-4068-bc8e-1f5329cb9599]
# processed record [483] with id [d6c35d5c-d677-4777-bf82-abfe3fb36ffe]
# processed record [484] with id [23eff03a-2742-498c-a0f7-ee45ab63a36c]
# processed record [485] with id [26db52f9-6abd-457a-ac50-ac15358d9559]
# processed record [486] with id [d45f9950-9540-44e5-a2bb-5b98ab40617d]
# processed record [487] with id [731b9ade-b4c3-42ef-b60d-29f330816e91]
# processed record [488] with id [835722a9-f718-4c17-8e32-3a9aca755b80]
# processed record [489] with id [2ada565e-196c-4e7c-8458-de753588f6cf]
# processed record [490] with id [7f26075f-44ee-4340-8f35-9670b92f5db9]
# processed record [491] with id [00b29c6d-56d4-4f83-bfe3-cccb47445e1b]
# processed record [492] with id [74a431f8-cfd7-4bef-a3ca-5bd67b024c67]
# processed record [493] with id [b2312541-32bd-48b5-a396-5f6fdda43b82]
# processed record [494] with id [c800127e-7ee2-4a2c-a53d-03dc69cb7c5e]
# processed record [495] with id [fef7f2da-78f0-4519-a4e0-3d0428b788dc]
# processed record [496] with id [668b0e61-0a0b-4d39-adec-56f6c98dfde9]
# processed record [497] with id [98ed2788-fef1-4f3a-9716-6ab4563c1a9c]
# processed record [498] with id [4cf4b39d-aea9-4db4-9380-7c6b80c92209]
# processed record [499] with id [02c522ae-eb56-4157-9fbe-159b3d64556d]
# processed record [500] with id [8e48b089-7f3f-4232-8d24-4d2d39e3c565]
# processed record [501] with id [f54e6580-f0d1-420b-b43c-28445d1bfcb1]
# processed record [502] with id [f23a0985-f525-45e3-856e-dbea854ec7fd]
# processed record [503] with id [f6a870f2-510d-4cb6-98e8-f9b7f75ab5ad]
# processed record [504] with id [fba1c408-164d-4550-b6e9-808b159f544f]
# processed record [505] with id [edc20903-1522-42cd-9165-9f84d95ab924]
# processed record [506] with id [2d97a964-4fbd-4017-9e32-a8d60bece8ee]
# processed record [507] with id [7b31f40a-89b0-4042-b45a-289a422371c2]
# processed record [508] with id [38a7783b-9241-4b2e-80a5-52d6ed218458]
# processed record [509] with id [133c3579-0898-4635-89e9-d6f71be9d6db]
# processed record [510] with id [93927742-3665-4797-bebe-0ddc63a595ca]
# processed record [511] with id [079cfdeb-e5c4-481c-a0b8-81ccd057cc7c]
# processed record [512] with id [6901564f-1713-40b5-8d3f-bcedf0b05a82]
# processed record [513] with id [8393bfab-3408-45c2-9ffc-9028dbc73e2a]
# processed record [514] with id [2e0bc573-ed24-41a5-ba09-a5232f195f8d]
# processed record [515] with id [14617054-09b1-4f66-9ce8-914d1b3e1843]
# processed record [516] with id [cc2999bb-a0a5-43a6-b584-31dee7655abf]
# processed record [517] with id [e6b0d73e-885b-40b1-b413-55689092fd95]
# processed record [518] with id [4f8413da-b7ac-42c7-9f36-c854d57bddf8]
# processed record [519] with id [cf86fe24-7832-406f-b4d5-4189e323ab82]
# processed record [520] with id [810bee1f-9ffa-4afa-a2d3-c84239cac745]
# processed record [521] with id [e7fba37c-443b-479c-b790-d704c03bb45f]
# processed record [522] with id [adc2a886-8e1a-4e5d-8f17-69291cf97f10]
# processed record [523] with id [c398fe1a-6caa-49bc-97bc-e094e7dafc25]
# processed record [524] with id [8f7e9fde-0f16-4a78-8fb3-117114d70a87]
# processed record [525] with id [8aab261d-8834-447f-9100-7532b9f75063]
# processed record [526] with id [d042b50a-e43e-41af-8b94-0ffbba689e97]
# processed record [527] with id [0faf851e-c7c2-4868-90b1-4ab74d9b8f10]
# processed record [528] with id [9fdba584-5b6d-4e60-a8fc-bac3fafce559]
# processed record [529] with id [6928f0ed-a9f8-4b62-a8f9-a4a708163929]
# processed record [530] with id [7c229a10-4091-47dc-abe9-889c251e4507]
# processed record [531] with id [a59cd3c7-b033-46db-bf87-48b764e2e563]
# processed record [532] with id [757295d5-b618-41ca-9072-c5f8dadc6c8a]
# processed record [533] with id [9962c4da-57e6-42f6-9fa2-9a50cbc87b97]
# processed record [534] with id [55fc6ba6-b301-4174-a4d2-ce4117682bdd]
# processed record [535] with id [8fc3d424-1bce-439d-a549-0cb42044bf2a]
# processed record [536] with id [b8503989-a83e-4c2b-8746-1fe357a72ed3]
# processed record [537] with id [d68f2723-c0b0-4a6e-a781-0d81463796b1]
# processed record [538] with id [31c9edc9-153a-4e8b-be9d-332984f93076]
# processed record [539] with id [47b1e171-2b0d-48d3-b11b-882338d909d9]
# processed record [540] with id [062926c9-f1eb-4e8f-bcb6-b6f2ca9dce00]
# processed record [541] with id [026b5ebd-dc5b-4c9c-b7b5-504edbc4f44c]
# processed record [542] with id [4e272d24-dad7-43fc-8c29-01f08b521062]
# processed record [543] with id [83462fa6-c412-4f32-9a97-8d7dd5017de0]
# processed record [544] with id [10fc28bc-b926-42b3-bb77-bd2454e711bf]
# processed record [545] with id [2515463c-876b-4895-ba60-6c4b6acb2285]
# processed record [546] with id [d4f77539-9536-4114-905d-89ddefb7bdf0]
# processed record [547] with id [d5551467-1a7e-4ba3-b40b-c060bcc6da07]
# processed record [548] with id [7efaeea1-48d7-4474-9f80-0ff75cde43c4]
# processed record [549] with id [72c69296-0f47-4c11-843b-85410c63be3b]
# processed record [550] with id [c0a6d619-09c6-4cd9-9008-d2c926ff7701]
# processed record [551] with id [efc4fac7-d3c4-48fe-bb20-cd584200bb4f]
# processed record [552] with id [f9ca4760-bac1-4717-859c-5fbcd211e663]
# processed record [553] with id [4a5b4471-6a36-4959-bec6-2c4fce5cdc5a]
# processed record [554] with id [906fa5ec-5f0c-4ac6-8e44-ff2609554b1b]
# processed record [555] with id [c5082d80-b2c7-4137-babd-4d23bd81a05b]
# processed record [556] with id [ef831c95-ddd9-47cb-9814-325b0861c850]
# processed record [557] with id [9ca8deda-e443-4683-8394-4cf1a4457c4d]
# processed record [558] with id [d5e7a6a8-c390-4b2a-9a22-314d4478a1cb]
# processed record [559] with id [3e8c46b9-5336-43af-8ec6-38c24de20652]
# processed record [560] with id [bfb952c7-c75e-46c1-86b8-ca72fa43e9b2]
# processed record [561] with id [822764e2-c734-49c2-865c-ad2ead4539e2]
# processed record [562] with id [237daa33-aec7-4bb1-9b28-97d7da9b9915]
# processed record [563] with id [27539392-dd8d-42a5-8028-91dace818f03]
# processed record [564] with id [bb7c447d-a672-4cc3-b173-814a114ffce7]
# processed record [565] with id [5a11da61-f1f0-4dd8-a554-6c574a7960b3]
# processed record [566] with id [1c435776-5112-4509-8376-65579f108c2b]
# processed record [567] with id [5d2022b8-f077-480c-8011-d00cae24a6fb]
# processed record [568] with id [8ead8e27-3322-4d1d-b187-9f240a72b458]
# processed record [569] with id [36aed37a-7e18-4194-951f-be3538a0f66a]
# processed record [570] with id [46100ae6-ac66-4841-88a0-0e31c0364f6d]
# processed record [571] with id [37107e1f-3bbc-4bde-b1c1-d14ac960d6d4]
# processed record [572] with id [b4c10138-84e8-4c79-ad3f-b3b30735c8b1]
# processed record [573] with id [74b18099-1fa4-4bee-86c5-7630fef6158f]
# processed record [574] with id [8edf0115-d585-46f9-8a0b-8cbd184318aa]
# processed record [575] with id [bcd0d7ce-354d-41d0-93ba-f8c4ec8ef90e]
# processed record [576] with id [2167a1d1-d003-46e0-820f-f0cf25a63d9c]
# processed record [577] with id [11d8443a-dd26-4073-ace8-106465603ff0]
# processed record [578] with id [401ab29c-314e-4c10-8b98-46c1bafd009e]
# processed record [579] with id [5670aed2-4341-4816-afaf-b604f2a64fcb]
# processed record [580] with id [5916173c-8149-485e-b6c2-d0347e5382d0]
# processed record [581] with id [932659c3-03de-4f83-8218-556309506eef]
# processed record [582] with id [e40bdec0-4f70-4817-9947-42bdafdad200]
# processed record [583] with id [42b30924-3ea6-4b5e-aefb-46dc2e7f7a9d]
# processed record [584] with id [a24c8c66-9d28-475e-aa0d-907a15214e8a]
# processed record [585] with id [4dee17d3-a2d2-4fae-af0e-5c97b4e34cef]
# processed record [586] with id [36cea9f6-e09c-4dcf-90c8-04b1de030912]
# processed record [587] with id [52974012-5922-45bb-94c7-770feb10a131]
# processed record [588] with id [de16b365-0812-46b0-a9a7-39027e32407e]
# processed record [589] with id [7774e1ac-2280-4e5a-9614-d1b65f3b8e90]
# processed record [590] with id [07d9cc0f-bcf8-4731-88e3-89da9ce14a43]
# processed record [591] with id [b5fbedb3-b3a2-49e0-9295-4ec9e9eb620a]
# processed record [592] with id [dd2e8061-9807-4ad2-8981-aa37bd912890]
# processed record [593] with id [d6e4d23f-95c2-4f89-bc46-8ca4551fde7c]
# processed record [594] with id [724403d0-58ea-4798-b9da-8c93263e4d78]
# processed record [595] with id [30938335-ed95-46fa-80b3-19c7da0df943]
# processed record [596] with id [eaaf82e0-076e-4258-b1da-1b0dfd18b49a]
# processed record [597] with id [20ee4b46-f128-46f5-9b84-ddcc51faea53]
# processed record [598] with id [29ebe677-87d1-4ecd-95e7-a34eb380bccf]
# processed record [599] with id [fb1b0482-4c83-41f7-b8e2-03ee8850749c]
# processed record [600] with id [ccf1388c-9f30-47ca-ad27-1e9bc4e71533]
# processed record [601] with id [fcd13550-e7ea-46c9-bf35-ae9009f6f62b]
# processed record [602] with id [18f6839f-12ab-4a1c-8f73-aa2b34b529ed]
# processed record [603] with id [8e874f4a-d433-4c5e-95ac-e5a26a44d650]
# processed record [604] with id [5dad341e-979b-4c35-8a95-b4f3f3ca4c1c]
# processed record [605] with id [a69a094c-2ee8-4c83-9432-94e8f29656ab]
# processed record [606] with id [0e8e1ab4-5104-419a-909c-85a67e21e5f8]
# processed record [607] with id [ffa62fc8-5188-44b6-8a39-bc5e461dea16]
# processed record [608] with id [1d971eec-44aa-43fd-91aa-d6144559d7b7]
# processed record [609] with id [7e06792e-820b-4232-bab6-09f3e43f84f7]
# processed record [610] with id [5e61c2ee-412d-484d-82e6-f0cb75e49e68]
# processed record [611] with id [7946ef8a-528d-4141-a953-9d1e1634860b]
# processed record [612] with id [289eabde-a759-4656-8884-067177237efa]
# processed record [613] with id [abdd7d0b-c618-4d30-af32-7d986663e148]
# processed record [614] with id [25a821f7-f0ea-4731-90db-651e6e867ad5]
# processed record [615] with id [cd5d513a-53a5-4c28-9b14-9381689614f5]
# processed record [616] with id [1a62fdf9-65b4-4ad0-8806-c17e236a06a5]
# processed record [617] with id [39e6b590-9b01-4a30-82ab-30ce36677011]
# processed record [618] with id [0528c1e4-7fe3-444d-8140-93454666548e]
# processed record [619] with id [46689d5b-17c7-40d0-adeb-09f955c6567e]
# processed record [620] with id [62da4b9d-32d8-45cb-8120-7de69aa484bf]
# processed record [621] with id [8ccfe9da-9251-42d8-a723-c95b53f7347d]
# processed record [622] with id [12fa4a15-f6eb-470a-94e1-329150c02d49]
# processed record [623] with id [0a730322-ae05-45d8-b2be-e2685dd822e9]
# processed record [624] with id [5c863e2f-50bc-4a8f-8cdf-99b47b0085ff]
# processed record [625] with id [0cfa66d0-1d9f-4386-a315-4dd3ec0f5614]
# processed record [626] with id [c112a224-2849-44b2-ad4f-39d0faf40286]
# processed record [627] with id [41456153-5329-45d8-bfdc-c469507b55dc]
# processed record [628] with id [58ef9edd-781d-4b3a-aa68-0051bbf0da19]
# processed record [629] with id [d10f0974-684c-4b90-b76e-d11062459db4]
# processed record [630] with id [69de9720-7000-4e8b-a1e0-5294d2aa37b9]
# processed record [631] with id [3d70b9cb-d566-47be-888e-a90bb82a5636]
# processed record [632] with id [d8038681-302a-4a06-8b4a-c790504b84c9]
# processed record [633] with id [e78aad31-41cb-4686-aeb1-01c249b97b6d]
# processed record [634] with id [59acf6cd-8160-49fb-a629-4ba7a0aaebcb]
# processed record [635] with id [1936e978-677f-4b26-b418-a0c0af7b1e61]
# processed record [636] with id [4fa74224-4620-44a5-9367-0335e8c75ce4]
# processed record [637] with id [be9dd8cc-7f96-4a1f-b9e4-458a8cef933e]
# processed record [638] with id [c1cfbad0-d939-4752-8c77-85eb713a7296]
# processed record [639] with id [979270a6-e399-45c6-ba6c-38e6742ecca5]
# processed record [640] with id [170b5dc3-2652-49ba-9b69-207d0ee54929]
# processed record [641] with id [86003590-6ce6-4f93-865f-d656f955b756]
# processed record [642] with id [eb7b6172-9aa4-487b-8349-e7882e94f9bb]
# processed record [643] with id [47ae5b2f-187a-4ad9-9d1b-dd1c9b848194]
# processed record [644] with id [eb71102b-0560-443f-b292-33b1eb1aaa9e]
# processed record [645] with id [9e1aca2b-840c-427e-9ed7-3e431cd46c8c]
# processed record [646] with id [ecc86e40-de9d-4fbd-b62e-b46b0254bed4]
# processed record [647] with id [4a9b01ef-e34b-408f-8bee-917112eb6661]
# processed record [648] with id [b361af74-992c-4697-bad8-e9ccb0094e57]
# processed record [649] with id [49029017-eab1-42a1-9599-d29b064b4ead]
# processed record [650] with id [edecc6dd-b20e-4ec0-9ec1-925db676d219]
# processed record [651] with id [f5d2b091-f37b-4f9f-b74d-4ee7687064cf]
# processed record [652] with id [bfd9434b-0ce4-4234-b8ee-6a3d3952e4fb]
# processed record [653] with id [f4dd9c98-a91e-445a-8650-f88b9457ffe5]
# processed record [654] with id [6050fe86-ce35-4e24-9a94-de2f285ff511]
# processed record [655] with id [fdfccf5b-1fec-4310-93f4-2229e11cd36e]
# processed record [656] with id [541966bd-b95e-423a-b3e8-6f374617e25d]
# processed record [657] with id [f12e88aa-f367-4972-986f-ed2371d7fdac]
# processed record [658] with id [32978831-e19c-4d96-b308-5b3d1b2237a1]
# processed record [659] with id [2de441a8-8be9-49f4-beb3-83bdb78b5892]
# processed record [660] with id [bcd52baa-08a5-461e-a42a-ba0a603c3e5c]
# processed record [661] with id [f584368b-b8d0-4e3a-a8a0-bb6f34a297cd]
# processed record [662] with id [f0f49aa8-a63a-4160-835a-d5988fc03b36]
# processed record [663] with id [dafaaa17-0e49-4412-a863-761595f24488]
# processed record [664] with id [ed2d8008-9393-45d5-aa58-19cf5ac17a28]
# processed record [665] with id [403f41a9-235b-4810-bb56-812c775b1c49]
# processed record [666] with id [76b74038-c9f8-4618-a346-e3d0753e1409]
# processed record [667] with id [c6aaf78b-f9cc-45a0-ad19-397c051524e9]
# processed record [668] with id [81d29ecb-1a20-4c6a-ab57-8e10be1c24c8]
# processed record [669] with id [6a1016ea-aabb-4b45-8e4a-1ea56225cafc]
# processed record [670] with id [2a642cbe-8014-4b7e-aee5-63c2ab812c85]
# processed record [671] with id [1689244d-055f-4b86-9366-0cc13a9d5f2a]
# processed record [672] with id [a3e20f68-a51c-432e-90fd-bb9bf92bdc64]
# processed record [673] with id [812d7c46-1e6a-416e-b850-68c4bf45dd23]
# processed record [674] with id [c2c529d0-db78-4df8-aa06-800ed8e20595]
# processed record [675] with id [9cefe11b-ab09-4c1d-aec0-e1ff01112228]
# processed record [676] with id [41558cf7-cfff-48b8-ac21-ba57a69aa0e8]
# processed record [677] with id [80c1f593-60b3-4b9f-895d-bab6ef436622]
# processed record [678] with id [e6ed3b14-cae1-4c8a-958d-07f6e70cc3e6]
# processed record [679] with id [80690b18-ff44-4c4b-936e-a042b9991a7c]
# processed record [680] with id [11d23dd0-4324-43dd-9c86-6ab03065ede9]
# processed record [681] with id [ab7b21c9-9a2b-4c0f-81bd-76c4d37394ce]
# processed record [682] with id [10d9627a-d186-4d46-a9a0-ec3cdc406e1f]
# processed record [683] with id [46dbc87c-de15-476a-a35f-2ecd27f29320]
# processed record [684] with id [2bc5c120-b538-4594-b6dc-79d982b75668]
# processed record [685] with id [3fdb6ae6-3f6e-4b9c-abee-af3395b00e1b]
# processed record [686] with id [cf6dbd3a-6020-4cd9-a36d-79bd75b942fd]
# processed record [687] with id [e8590b75-0003-4e3a-ba1e-cc21fd5893c8]
# ...
# processed record [772] with id [02dfb75a-dd20-4ad1-a9bc-4f600604f599]
# processed record [773] with id [503217b0-b995-4320-8f42-3c52c361d229]
# processed record [774] with id [2a7333e4-bac9-481b-9e67-555e6c4972d2]
# processed record [775] with id [c0d1e625-ce94-482a-a7e8-5070ed1c80b4]
# processed record [776] with id [0318d68f-f64d-4adf-87d6-75f15b650540]
# processed record [777] with id [7d3e0ade-a8fc-48dc-a59c-3750ddbf6ef8]
# processed record [778] with id [36c35298-9ba3-4292-bef9-98cac8fc0e5d]
# processed record [779] with id [c49086de-c77e-4502-afe7-27bab9c1386d]
# processed record [780] with id [bda46090-f6e4-4b2f-8a34-79d92ccbb276]
# processed record [781] with id [9293b66c-3eae-40da-81ba-dc166b0ce97b]
# processed record [782] with id [0dd1b331-4483-451f-a88b-dedd3b4381c2]
# processed record [783] with id [58c2e9af-5628-40be-ac72-e12185d1e4af]
# processed record [784] with id [bc97ffea-a2bf-4615-8886-d75dc553fab3]
# processed record [785] with id [e8e6e2c1-dfd5-405f-bb07-78261292e65f]
# processed record [786] with id [91dd28da-1879-4ca1-af3d-facd5191a7ea]
# processed record [787] with id [32ca9fc8-167d-4cd8-84d4-c41910a6545f]
# processed record [788] with id [98fa4b32-a92d-4f73-910f-0f3ad9e347df]
# processed record [789] with id [55a2fe6e-65c3-41a0-928a-ee03377b9039]
# processed record [790] with id [1805acc0-ff57-4c3d-a887-7bfa636feba7]
# processed record [791] with id [837de906-b9bd-4aad-bc60-348db4412a0a]
# processed record [792] with id [cbad1285-6d19-4a95-a486-263cc4edc9ba]
# processed record [793] with id [0b7371a5-efaf-4e23-91da-5f25f2e47dbd]
# processed record [794] with id [76fff325-0e80-41d8-bfcb-0fc87d4c81bc]
# processed record [795] with id [4164956a-962c-42fd-b034-1cae87ff748a]
# processed record [796] with id [8e086f0b-3c51-42df-9cbe-ae33f7b9baa9]
# processed record [797] with id [decc49de-1da8-483c-8454-6b7999fa9a9b]
# processed record [798] with id [55dd3929-79a3-4ee3-a670-599761639c64]
# processed record [799] with id [492ebb01-225b-488f-b71f-5b9bec66207c]
# processed record [800] with id [38568ef5-c5cb-4556-b6eb-a25cd1167ec5]
# processed record [801] with id [6fa6187d-09d9-4c9f-9238-06d324586cd1]
# processed record [802] with id [36a7c9a2-3133-4c0d-9fd3-d3ccd9e84282]
# processed record [803] with id [705ebb98-074e-49da-9467-236f3e66b8a2]
# processed record [804] with id [eb9ee080-b0e9-4798-bf17-cbd44d23ae18]
# processed record [805] with id [c8bae661-d7ec-4d88-b2d0-aa86a3e8fc3f]
# processed record [806] with id [e1dbf3f1-021d-4f21-9f8e-ec1852abcd5f]
# processed record [807] with id [103d06c3-7bbe-4bb1-924d-875fdbdcb841]
# processed record [808] with id [9a7b6d5c-7b05-42d4-a5e6-de0270fb491f]
# processed record [809] with id [910f8b36-f451-4aca-ba16-8aaadbd66f87]
# processed record [810] with id [68fc3c2a-cca9-4fcb-a994-b496ffff7a2e]
# processed record [811] with id [a47725ed-14f6-4992-88f5-ea60a7fc8892]
# processed record [812] with id [e608c204-2e37-45e3-acc8-1155f51da7bb]
# processed record [813] with id [90044915-0d69-48d7-a721-171a7ce26ef8]
# processed record [814] with id [4e19d6df-6dce-4869-84af-400cb91f4f70]
# processed record [815] with id [5c3d9e5c-e5c1-4d92-b10e-d77a0cf89803]
# processed record [816] with id [c5ad55c1-14f6-4f7b-8dd2-882735a83c60]
# processed record [817] with id [b1e6003b-3b4c-4ee5-8baa-123ad6089af8]
# processed record [818] with id [34fb3aa9-729a-4229-8561-bb2aec2d7bf5]
# processed record [819] with id [4ce4d6f9-f665-4d80-a12e-83839c30abc0]
# processed record [820] with id [3d7b9f6f-af5e-4537-b2ab-53d75b38dd92]
# processed record [821] with id [5f0b197c-bde8-4d80-9e40-5fb33887b951]
# processed record [822] with id [4b2bd044-2dc7-4e8b-9d70-fd17259b06d8]
# processed record [823] with id [59ce964c-7c14-4fb8-ae60-52ecae81b621]
# processed record [824] with id [0e8dcddf-3caa-4a63-8241-81e09ffd8838]
# processed record [825] with id [f2dde641-78c8-46d1-b650-0b2b87f3d57a]
# processed record [826] with id [89e66a94-78f2-4a14-a7d5-fa2d3f61b945]
# processed record [827] with id [445f0401-39d5-4112-8129-24d411a21cf2]
# processed record [828] with id [b1431c3f-1cc5-4bc8-9ec0-f279cffc8139]
# processed record [829] with id [c07842fd-c988-46d9-93f9-b7534a032767]
# processed record [830] with id [73e96306-5d6a-499b-ab17-9ec3453ffdf9]
# processed record [831] with id [aad20edf-c37d-4c87-a7ad-2b213bca23ab]
# processed record [832] with id [c14f9d1d-4129-43e3-ac8b-dfa6e09f1b1f]
# processed record [833] with id [3965899e-f9a1-418a-915f-d530777a7b95]
# processed record [834] with id [ff167a0f-6f67-4a8d-8163-4cf5db4d5346]
# processed record [835] with id [97f0656e-ab5d-4000-b6af-c0ea71fcad24]
# processed record [836] with id [9831b7c2-0be2-450a-b18b-d713846e3046]
# processed record [837] with id [8dbd02bf-3a59-4947-945a-c21ac334fd5c]
# processed record [838] with id [efffe3a0-bc5a-4d70-8fb2-521ef0175e3e]
# processed record [839] with id [6fad86af-4e7c-4dcf-879c-0b28917fe7c4]
# processed record [840] with id [16a7c516-1198-4100-86b7-acc130956f05]
# processed record [841] with id [bac0c6a0-d33f-4d5f-91bb-3633ed30df93]
# processed record [842] with id [344dd0cd-f301-44b3-9bf9-d2d89fe875be]
# processed record [843] with id [0e34d0a4-f17b-4127-a733-c809fc75ae52]
# processed record [844] with id [8b581448-eaf3-4d1f-ae67-db5d7423c5c6]
# processed record [845] with id [280c65b8-5188-4132-879b-b9288a169402]
# processed record [846] with id [420c94fb-2468-47a6-b0f7-c5c095c80455]
# processed record [847] with id [740ec35d-faf6-4196-ab5e-f6c58c45f33c]
# processed record [848] with id [d4e8ac7f-ede3-4340-96e4-082411b4e245]
# processed record [849] with id [27520205-3ab6-46bf-a49e-95d88d203ccc]
# processed record [850] with id [fe11be7a-1570-4024-a32d-c386ed7123be]
# processed record [851] with id [acaf0ae1-cd99-4891-b6d6-9b1fef5c5d2d]
# processed record [852] with id [a044d9f5-b9cf-40a5-bc11-ad323a016727]
# processed record [853] with id [074dc6a3-73e8-4951-8b09-89608b6d1d61]
# processed record [854] with id [e2b4a4a3-49e5-470a-a624-aa8fc9792789]
# processed record [855] with id [fd5f3273-6dd4-490a-832c-566dadba28ff]
# processed record [856] with id [a011873e-0b81-4d2a-aabb-d527c6fecb59]
# processed record [857] with id [35941002-87cb-44bb-bbda-140ca3137155]
# processed record [858] with id [fbf5c211-4194-48f7-a8e6-28f31b38b67c]
# processed record [859] with id [e8f9dcd4-ee8b-43e4-b9ea-0b04499b362f]
# processed record [860] with id [d1055e3b-fa5b-4a31-9907-7a8249765cc6]
# processed record [861] with id [47991435-4375-456e-a5df-58507a07c35d]
# processed record [862] with id [2559b09f-4803-428c-a269-98e20cd27efd]
# processed record [863] with id [022c2497-3f47-4d74-ab27-377b3ea0560c]
# processed record [864] with id [9c90eff8-f73b-4c13-9c9b-7e61450d38fe]
# processed record [865] with id [c2f70817-6931-4e57-8698-4a439b5c83af]
# processed record [866] with id [6f207f18-0297-48ad-84b9-4661af6e1ed0]
# processed record [867] with id [0d54eacd-e001-4dd1-a927-93f38e125ab0]
# processed record [868] with id [f91485ea-e4ca-4234-8d2b-75403afcef9e]
# processed record [869] with id [1184d998-5361-4c59-8942-61a2c5f11d83]
# processed record [870] with id [5916418f-9721-47ee-97e5-efd8930d4b02]
# processed record [871] with id [f5505085-b3bd-4690-8a30-f34f1a0a13c3]
# processed record [872] with id [dfec7a2b-64c2-4708-8ad0-f4b3617e387b]
# processed record [873] with id [8976bf37-2e31-446a-be95-8f3bb3931b2a]
# processed record [874] with id [050816bc-132c-452e-b1c3-e2f53903cf39]
# processed record [875] with id [55e13ade-b377-4c3d-9b15-2f963be4f8fb]
# processed record [876] with id [07b14295-1181-4160-b942-75aff8a1e22a]
# processed record [877] with id [9aae44c2-c514-412e-a702-df1fb7ee4387]
# processed record [878] with id [92cba9b6-990b-4779-b3f0-7f5ee71fb95b]
# processed record [879] with id [fa7fa551-c947-42db-b239-40ae1c275a9a]
# processed record [880] with id [456d0f71-c7bc-4f4e-aaa8-052efd23e3b3]
# processed record [881] with id [61887705-15a8-4b85-b064-3bddf9777f89]
# processed record [882] with id [1f3e37df-fd25-4c05-8b25-a979503ce3ff]
# processed record [883] with id [abd60c35-59f4-4f71-a002-8858c8a2e0fb]
# processed record [884] with id [89555037-89ec-4384-a55b-3a18170dd0c4]
# processed record [885] with id [ef1e8ab4-66f8-485d-96a8-344c183407bc]
# processed record [886] with id [7d2de927-40da-48a3-91bd-bbef517caf29]
# processed record [887] with id [be5fe57b-cc07-4479-8fa0-70e69d0ec1ec]
# processed record [888] with id [1d1f780f-9912-4d89-83e3-d6f54a76d55f]
# processed record [889] with id [ac967e24-8d64-45c8-8d1e-cbfd8581b320]
# processed record [890] with id [7ba07e18-6a5a-471e-9092-c26e6f20f96c]
# processed record [891] with id [cd896ef1-9673-4cc4-888d-92824b0c858e]
# processed record [892] with id [80b4c53e-d505-4f5f-8798-a9e71eeb59f5]
# processed record [893] with id [f9aba28b-045a-4557-a2fa-2ff00394e228]
# processed record [894] with id [d6c5b649-6432-4c7d-877d-a43cb585aacf]
# processed record [895] with id [9d94e74f-8b6b-4bae-a180-719fc3a76817]
# processed record [896] with id [84d6faf8-0783-4a40-beca-4379e0105161]
# processed record [897] with id [7a1fbd24-bc93-4267-a5e1-d239803c9c0b]
# processed record [898] with id [4239f215-5ec8-48f8-b8da-e4f5ea2fdf40]
# processed record [899] with id [9b73c442-339d-43e2-9dae-02a754222310]
# processed record [900] with id [e116cd42-9588-44dc-843e-389141311d5d]
# processed record [901] with id [e56f1718-6e25-48ef-b3e7-42f3cb981dfd]
# processed record [902] with id [3ee1cea7-9e52-4ec1-9d83-4621e4ff4d02]
# processed record [903] with id [6920f863-1535-40e2-bc7c-93c22e0ad1e8]
# processed record [904] with id [d6209f65-44b9-4908-8a3e-53a460606d34]
# processed record [905] with id [ba14a347-7cb2-4a3a-81ac-30f77100c4a1]
# processed record [906] with id [077a235f-622d-40cc-a0fc-10035c330864]
# processed record [907] with id [0a1a3733-cbbe-4eb8-8b6d-d15434880289]
# processed record [908] with id [df93e17d-5c3b-46c1-812c-a220c0e21eda]
# processed record [909] with id [1b749efe-8d7f-4b63-827b-aa383647221f]
# processed record [910] with id [721739a3-54ff-4118-9c92-a46fa1dd8721]
# processed record [911] with id [25537fd2-d763-4f54-8f71-f6ca521b1069]
# processed record [912] with id [672b4574-cda2-4212-b3ce-7e1d2c29f5a6]
# processed record [913] with id [22f095ea-3776-419a-9102-7038915245c1]
# processed record [914] with id [f8dd339b-e619-477f-a344-175efdf458b5]
# processed record [915] with id [d3ffc09c-9ff1-43bb-aac7-08c72f07e16a]
# processed record [916] with id [56a399e4-f791-4b27-82ae-3379727779f4]
# processed record [917] with id [f122c1bb-870c-4c0d-a840-bddf810641d4]
# processed record [918] with id [cd0351ec-6446-4265-95d5-92a339c87424]
# processed record [919] with id [58da0e7a-8d44-4745-bdd8-540bc59ece66]
# processed record [920] with id [23ca229e-a10d-4b19-92d4-2ed627371c86]
# processed record [921] with id [71458c93-2d60-4825-babf-fd1091ad1f90]
# processed record [922] with id [514d177e-7671-4c75-927c-9fb3570372b3]
# processed record [923] with id [ac843602-838f-4d6a-86ab-3effb64e5ef5]
# processed record [924] with id [b0305db2-f355-47cc-9ad2-cd723b7ce2d7]
# processed record [925] with id [0169a6d9-b623-4718-b6d8-5416f8c39f94]
# processed record [926] with id [dc9c58b4-7221-40c0-827b-797480f5df2a]
# processed record [927] with id [b005ead6-e325-4742-9b7e-c2fa9d2cc29b]
# processed record [928] with id [3a93ceb9-a679-4c82-8bfc-efbeb0b6faf8]
# processed record [929] with id [b09420f4-dc43-48f8-b615-1ec0a81b2ed0]
# processed record [930] with id [9e3a7fc4-0d57-454b-ae63-c98fa1252c21]
# processed record [931] with id [63558792-7715-4144-a033-898bf49e46e8]
# processed record [932] with id [1fa85f48-9768-4145-b92d-040d3ca06380]
# processed record [933] with id [df48ac18-6475-49c0-ba93-bc5232bf73a5]
# processed record [934] with id [86953e08-d850-467c-91f9-2cc1cd6063bb]
# processed record [935] with id [6c74bc94-b4bf-46a5-ae81-6e3f1eddd965]
# processed record [936] with id [e20611d3-7dd3-4ea1-8f40-47dfb2c691a8]
# processed record [937] with id [528da65a-f4ca-4635-afb1-997f525e5d83]
# processed record [938] with id [4baa14b7-9ae8-4ca8-9a79-32f626230f48]
# processed record [939] with id [9edf14e0-c657-478e-806e-1af63a54a221]
# processed record [940] with id [68110f07-2d08-46d6-a3b1-6a9a5cefe254]
# processed record [941] with id [3abddf02-925b-4a06-b568-bca921d9f635]
# processed record [942] with id [33100774-f7ab-431f-8184-5a9179b1583c]
# processed record [943] with id [af396358-ac75-44f9-8fe5-c9862e9dcefc]
# processed record [944] with id [d6424152-c272-49c6-ab46-c42ab70935de]
# processed record [945] with id [a28b057c-9401-49d7-af37-14b2d6c068c2]
# processed record [946] with id [e9cc1000-94aa-4444-bdc1-682f432fda80]
# processed record [947] with id [beb12238-f614-43ff-a42b-58f137485bff]
# processed record [948] with id [005ec94f-318c-41a2-851c-534bd208e1eb]
# processed record [949] with id [364abdc3-1137-4ca9-a78d-d26b22341e51]
# processed record [950] with id [a5c134c6-b2f0-43db-9a0f-07547f6f45bf]
# processed record [951] with id [8d56338d-acd7-4314-8364-bc8658ceb4ef]
# processed record [952] with id [c20c69d8-5ec1-47ad-a48b-921bd0bd60c5]
# processed record [953] with id [976bd336-ceb9-4634-a50f-2c8b3b19db97]
# processed record [954] with id [13a9ab2b-4365-40f4-a61e-c4f211df2488]
# processed record [955] with id [f116fd98-26a5-4872-9764-37921e700286]
# processed record [956] with id [76714c99-16b6-4ce5-9e01-6f81f8c24e5f]
# processed record [957] with id [bcaf4834-4703-479a-a625-fa41114edaeb]
# processed record [958] with id [e0dff1c2-425f-4815-bbc6-7b5ba53ba090]
# processed record [959] with id [6968690a-0f2e-4bc4-a787-536f43ebd1a8]
# processed record [960] with id [20a2745d-1200-4266-9991-f8a049da3f12]
# processed record [961] with id [80cf9375-41af-4682-882f-bae57b668a91]
# processed record [962] with id [0d5b1b4a-1bb4-4ba3-9996-0c77e2c13dd9]
# processed record [963] with id [eb0d6a49-d98c-425d-ba72-9cdaeba5f287]
# processed record [964] with id [7705f9ae-4b11-46a5-8afd-35f512709537]
# processed record [965] with id [f5878bbf-0b8b-4350-92a3-68976e1a38f7]
# processed record [966] with id [9941713b-34d3-4888-9cb3-da29cddf8e31]
# processed record [967] with id [955ce440-0df4-494d-9782-949f015a6bff]
# processed record [968] with id [828a1fb8-2c42-417a-bf90-a2cfcf85a91b]
# processed record [969] with id [597593d3-4cfc-43df-b19c-34de99257576]
# processed record [970] with id [aea897b2-baf4-4f4d-8db2-5d73904933f4]
# processed record [971] with id [87bbba3e-1df7-4a93-beb8-e1aea517b894]
# processed record [972] with id [45a94af7-005f-44b0-b772-53d6acedb640]
# processed record [973] with id [4137607c-4f94-4072-b359-41ac144c6646]
# processed record [974] with id [755b5d6d-d111-4646-bd7e-22a28cf7b6e2]
# processed record [975] with id [2afbfcca-9b30-42fb-96d9-f130fdbf3c0e]
# processed record [976] with id [d77157d7-7347-499c-868f-fc6a4ecbfaa3]
# processed record [977] with id [0b19a8c0-d023-4a02-a063-6701061734d8]
# processed record [978] with id [2a029fef-007f-4dc8-8144-4fa22f731a7a]
# processed record [979] with id [a8dcc6a8-ab22-4f05-b650-4575f23a8de7]
# processed record [980] with id [fd7ff3c2-03bc-419b-b190-c42ce8b270c6]
# processed record [981] with id [1fa38b50-6be0-4e65-84f0-4511a60f5f70]
# processed record [982] with id [712a9d71-b50e-4010-800e-a417dfffeed1]
# processed record [983] with id [fdf8f914-d1a6-4762-92de-7a442e46c30f]
# processed record [984] with id [6da31807-2230-46cc-81e5-17f7a8101cac]
# processed record [985] with id [377a7010-c111-4b0c-9665-ae70e030270d]
# processed record [986] with id [45eb5d2f-280e-47b1-b941-ed475b90c518]
# processed record [987] with id [b3bed305-cbba-4ff9-b600-c993573da7a8]
# processed record [988] with id [2892a5c1-9b8f-4a31-b36f-b202cd36784e]
# processed record [989] with id [9b250f2c-a6d3-48b6-8166-312e28a1415a]
# processed record [990] with id [baf01d84-c742-4689-be11-7f212f43bc8a]
# processed record [991] with id [a2432677-6804-4a18-abbe-525f77aed60f]
# processed record [992] with id [43209b17-c942-4269-928e-68fd98b75070]
# processed record [993] with id [9639400f-c264-432d-a3aa-9b6ab574609f]
# processed record [994] with id [64f204de-ab1e-4d42-b2e8-bc8733ce05e8]
# processed record [995] with id [24e9dd52-c464-44e9-a903-ffd271916ae2]
# processed record [996] with id [ccfd3bec-3daf-4400-9c4c-9755ed8049da]
# processed record [997] with id [ccb89b81-a085-4698-853a-2a0fb5d9c78e]
# processed record [998] with id [d38e2f17-0923-459b-9879-fee35fdcf4f7]
# processed record [999] with id [92253317-3b27-4792-88ac-d85ccb7cf1f8]

# %% [markdown]
# #### Step 2: Create Embeddings for each of the JSON Files

# %%
import os
os.environ['SHELL'] = '/bin/zsh'  # or '/bin/bash' if available

# %%
# %pip install -q python-dotenv openai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI()

response = client.embeddings.create(
    input="Hello world",
    model="text-embedding-3-small"
)

print(len(response.data[0].embedding))
print(response.data[0].embedding)
# Out:
# 1536
# [-0.002153123263269663, -0.04904741793870926, 0.020912760868668556, 0.03131536394357681, -0.04529817774891853, -0.026352230459451675, -0.028933674097061157, 0.06032586470246315, -0.025722235441207886, -0.0148509806022048, 0.01540414709597826, -0.030086103826761246, -0.020359596237540245, -0.03340510278940201, 0.025829795747995377, 0.01422098558396101, -0.07006774097681046, 0.012400145642459393, 0.014797200448811054, 0.04886302724480629, 0.020774470642209053, -0.008896758779883385, -0.015165978111326694, -0.016579624265432358, 0.02592199109494686, -0.0028349775820970535, -0.024323955178260803, 0.024277856573462486, 0.0018390860641375184, -0.05574687570333481, 0.023094695061445236, -0.0454825684428215, -0.008681639097630978, 0.0031288473401218653, 0.00451368372887373, 0.0018035528482869267, 0.026690276339650154, 0.010179798118770123, -0.012000637128949165, -0.011508933268487453, -0.014912443235516548, -0.02315615862607956, 0.025399556383490562, 0.036785561591386795, -0.035525571554899216, 0.021296905353665352, -0.06306096911430359, 0.04035041481256485, 0.05353420972824097, 0.06161658838391304, -0.033650953322649, -0.006599582266062498, 0.02547638490796089, 0.10964986681938171, -0.004686548374593258, -0.03948993235826492, 0.007122016977518797, 0.05156739801168442, -0.026352230459451675, 0.027904169633984566, 0.030470246449112892, 0.0206361785531044, 0.017286449670791626, 0.012338683009147644, 0.001112094847485423, 0.007083602715283632, -0.0370621457695961, 0.023571033030748367, -0.010679183527827263, 0.04087284952402115, -0.002068611793220043, 0.03133072704076767, -0.04271673411130905, -0.006707142107188702, -0.04723425954580307, -0.02174251154065132, -0.04563622549176216, 0.0009805257432162762, 8.073011849774048e-05, -0.04738792032003403, -0.03294413164258003, 0.023432740941643715, -0.05288885161280632, -0.05620785057544708, -0.022464700043201447, 0.018100833520293236, -0.035894349217414856, 0.0011322624050080776, -0.006034891586750746, -0.019852526485919952, 0.011270764283835888, 0.0010391076793894172, -0.020067647099494934, 0.045144520699977875, 0.04136455059051514, 0.005450993776321411, -0.007306405808776617, 0.03921334818005562, 0.05977270007133484, -0.008666273206472397, 0.027873437851667404, -0.02397054247558117, 0.026213940232992172, -0.01601109281182289, 0.0088737104088068, 0.011739419773221016, -0.000166982295922935, -0.04615866020321846, -0.02504614368081093, 0.0045866710133850574, -0.1122313067317009, -0.01536573190242052, 0.0134066017344594, -0.031161705031991005, 0.005162885878235102, 0.03306705504655838, 0.08143838495016098, -0.05740637704730034, 0.01731717959046364, -0.06803946197032928, 0.02092812769114971, 0.0027312589809298515, -0.01768595725297928, -0.05848197638988495, -0.05795954167842865, -0.02633686549961567, -0.010525526478886604, 0.037553850561380386, -0.04173332825303078, 0.007210369687527418, 0.028902942314743996, 0.026797836646437645, 0.01634913869202137, -0.006630313582718372, -0.04701914265751839, 0.012730509042739868, -0.03558703511953354, -0.022879576310515404, -0.03441924229264259, 0.03973578289151192, 0.053718600422143936, -0.05101422965526581, 0.002760069677606225, -0.04194844886660576, -0.0034361619036644697, -0.04197918251156807, -0.002112788148224354, 0.03300559148192406, -0.02315615862607956, 0.005639223847538233, 0.04394599422812462, 0.05854343995451927, -0.05802100524306297, 0.015227440744638443, 0.02941001206636429, -0.007291039917618036, 0.035341184586286545, -0.03503387048840523, -0.011109424754977226, 0.007394758518785238, 0.019883258268237114, 0.031868528574705124, -0.036601174622774124, -0.016134018078446388, -0.011424422264099121, 0.0034688140731304884, -0.0019351219525560737, 0.004164113663136959, -0.04775669425725937, 0.007102809846401215, 0.01724035106599331, 0.014159522019326687, -0.02311006188392639, -0.05620785057544708, -0.013583307154476643, 0.014989271759986877, 0.01742473989725113, -0.052427880465984344, -0.010702232830226421, -0.04065772891044617, 0.041548941284418106, 0 ...

# %%
import os
import json

transformed_dir = "../data/transformed"
embedded_dir = "../data/embedded"

if not os.path.exists(embedded_dir):
    os.makedirs(embedded_dir)
    
def prepare_embedding_str(review_json):
    return f"REVIEW_TITLE: {review_json['review_title']} REVIEW_TEXT: {review_json['review_text']} HOTEL_NAME: {review_json['hotel_name']} HOTEL_CITY: {review_json['city']} HOTEL_STATE: {review_json['hotel_state']}"
    
client = OpenAI()
for file in os.listdir(transformed_dir):
    with open(f"{transformed_dir}/{file}", "r") as f:
        review = json.load(f)
        
        ## start here
        embedding_str = prepare_embedding_str(review)
        response = client.embeddings.create(
            input=embedding_str,
            model="text-embedding-3-small"
        )
        
        review['embedding'] = response.data[0].embedding
        
        with open(f"{embedded_dir}/{file}", "w") as f:
            json.dump(review, f, indent=2)
